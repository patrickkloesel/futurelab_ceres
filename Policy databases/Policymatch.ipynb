# %%
#pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import os

# %%
y = pd.read_csv("C:\\Users\\laura\\OneDrive\\Documenti\\LAURA\\MCC\\y_cp.csv")

# %%
z = pd.read_csv("C:\\Users\\laura\\OneDrive\\Documenti\\LAURA\\MCC\\z_un.csv")

# %%
yx = y.to_numpy()

zx = z.to_numpy()

yp = y.astype(str)

zp = z.astype(str)

# %%
new = pd.DataFrame()

for i in range(len(y)):
    for j in range(len(z)):
        if y.iloc[i,0]==z.iloc[j,0] and y.iloc[i,1]==z.iloc[j,1]:
            new = new.append(y.iloc[i,:])
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_25276\3844479469.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new = new.append(y.iloc[i,:])
# C:\Users\laura\AppData\Local\Temp\ipykernel_25276\3844479469.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new = new.append(y.iloc[i,:])
# C:\Users\laura\AppData\Local\Temp\ipykernel_25276\3844479469.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new = new.append(y.iloc[i,:])
# C:\Users\laura\AppData\Local\Temp\ipykernel_25276\3844479469.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new = new.append(y.iloc[i,:])
# ...

# %%
new
# Out:
#                        Country  \
# 163                  Australia
# 234                  Australia
# 266                  Australia
# 309                  Australia
# 380                  Australia
# 399                  Australia
# 420                    Austria
# 921                     Canada
# 949                     Canada
# 4979            United Kingdom
# 5029            United Kingdom
# 5030            United Kingdom
# 5031            United Kingdom
# 5041            United Kingdom
# 5058            United Kingdom
# 5064            United Kingdom
# 5166            United Kingdom
# 5209  United States of America
# 5447  United States of America
# 5539  United States of America
#
#                                                  Policy
# 163                            Emissions Reduction Fund
# 234                                 Safeguard Mechanism
# 266      NSW and Queensland land-use change legislation
# 309                                        Solar Cities
# ...

# %%
e = pd.read_csv("C:\\Users\\laura\\OneDrive\\Documenti\\LAURA\\MCC\\eea.csv")

# %%
new_eea = pd.DataFrame()

for i in range(len(e)):
    for j in range(len(z)):
        if e.iloc[i,0]==z.iloc[j,0] and e.iloc[i,1]==z.iloc[j,1]:
            new_eea = new_eea.append(e.iloc[i,:])
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_19168\2509308830.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_eea = new_eea.append(e.iloc[i,:])
# C:\Users\laura\AppData\Local\Temp\ipykernel_19168\2509308830.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_eea = new_eea.append(e.iloc[i,:])
# C:\Users\laura\AppData\Local\Temp\ipykernel_19168\2509308830.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_eea = new_eea.append(e.iloc[i,:])
# C:\Users\laura\AppData\Local\Temp\ipykernel_19168\2509308830.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_eea = new_eea.append(e.iloc[i,:])
# ...

# %%
new_eea
# Out:
#      Country                          Name.of.policy.or.measure
# 0    Austria                   EU Emission Trading Scheme (ETS)
# 288  Finland                               Promoting wind power
# 290  Finland  Promoting biogas in electricity and heat produ...
# 292  Finland                             Energy Audit Programme
# 308  Finland           Farm reparcelling to cut down energy use
# 314  Finland                              Promoting solar power
# 430   Greece     Promotion of natural gas in residential sector
# 431   Greece        Promotion of natural gas in tertiary sector
# 432   Greece               Promotion of natural gas in industry
# 514  Ireland                               Greener Homes Scheme
# 517  Ireland  Replacement of coal fired electricity generati...
# 518  Ireland  Renewables - With Measures scenario (Electrici...
# 520  Ireland  Directive 2009/28/EC on the promotion of the u...
# 952   Sweden  Training programs in building for low energy c...

# %%
#try matches between cp and eea 

m = pd.DataFrame()

for i in range(len(e)):
    for j in range(len(y)):
        if e.iloc[i,0]==y.iloc[j,0] and e.iloc[i,1]==y.iloc[j,1]:
            m = m.append(e.iloc[i,:])
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_25276\72404945.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   m = m.append(e.iloc[i,:])

# %%
m
# Out:
#      Country Name.of.policy.or.measure
# 425  Germany      Renewable Energy Act

# %%
#new
